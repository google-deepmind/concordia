# %% [markdown]
# # MCP Tool Use Example
# This notebook demonstrates MCP tool support in Concordia.

# %%
# Setup
import asyncio
import os
import sys

# Create test file with mission data
mission_file = '/tmp/secret_mission.txt'
with open(mission_file, 'w') as f:
  f.write('CLASSIFIED MISSION BRIEFING\n')
  f.write(
      'Agent Alice: Your task is to retrieve the blue diamond from the'
      ' museum.\n'
  )

# %%
# Imports
from collections.abc import Collection, Sequence
from typing import Any
from concordia.contrib.tools.mcp import mcp_client
from concordia.language_model import language_model

# %%
# Mock model for testing
class MockModel(language_model.LanguageModel):

  def sample_text(
      self,
      prompt: str,
      *,
      max_tokens: int = 1000,
      terminators: Collection[str] = (),
      temperature: float = 0.0,
      top_p: float = 1.0,
      top_k: int = 1,
      timeout: float = -1,
      seed: int | None = None,
  ) -> str:
    if "tool use" in prompt.lower() or "read" in prompt.lower():
      return (
          '{"tool": "read_file", "arguments": {"path":'
          ' "/tmp/secret_mission.txt"}}'
      )
    return "I need to check my mission briefing."

  def sample_choice(
      self,
      prompt: str,
      responses: Sequence[str],
      *,
      seed: int | None = None,
  ) -> tuple[int, str, dict[str, Any]]:
    return 0, responses[0], {}


model = MockModel()
print("Model initialized")

# %%
# Setup MCP client and test tool use
server_path = os.path.join(
    os.getcwd(), 'concordia/contrib/tools/mcp/servers/file_reader_server.py'
)

test_client = mcp_client.MCPClient(
    server_command=sys.executable,
    server_args=[server_path],
)


async def run_test():
  await test_client.connect()
  result = await test_client.call_tool('read_file', {'path': mission_file})
  await test_client.disconnect()
  return result


result = asyncio.run(run_test())
print(result)

# %% [markdown]
# ```
# Copyright 2026 DeepMind Technologies Limited.
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#     https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.
# ```
